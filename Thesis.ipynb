# %%
### Import the data from excel:

xx = read.csv("C:\\Users\\Jan\\Desktop\\Stats hons\\Thesis\\archive (1)\\bt_dataset_t3.csv", header = TRUE)


### Take out the image variable:

logical = rep(TRUE, times = ncol(xx))

logical[1] = FALSE

logical[ncol(xx)] = FALSE

xx = xx[,logical]

## Our data without the image and target variables:

head(xx)
# Out:
#   Mean      Variance  Standard.Deviation Entropy   Skewness Kurtosis  Contrast
# 1 23.448517 2538.9856 50.38835           0.6511741 1.984202  5.421042 181.46771
# 2  4.398331  834.8530 28.89382           0.9535317 6.495203 43.349355  76.74589
# 3  3.244263  642.0592 25.33889           0.9660645 7.772860 61.756034  81.75241
# 4  8.511353 1126.2142 33.55911           0.8687651 3.763142 15.107579 362.29121
# 5 21.000793 2235.3170 47.27914           0.6847244 1.936029  4.722343 312.43923
# 6  0.000000    0.0000  0.00000           1.0000000       NA        NA   0.00000
#   Energy    ASM       Homogeneity Dissimilarity Correlation Coarseness
# 1 0.7815569 0.6108312 0.8470333   2.7654114     0.9685761   7.458341e-155
# 2 0.9727695 0.9462805 0.9807616   0.5486053     0.9597505   7.458341e-155
# 3 0.9801609 0.9607154 0.9850659   0.5404114     0.9442587   7.458341e-155
# 4 0.9217862 0.8496899 0.9492953   2.7657252     0.8590271   7.458341e-155
# ...

# %%
names = colnames(xx)

names[3] = "Standard Deviation"

options(repr.plot.width = 5, repr.plot.height = 5)


for(i in 1:ncol(xx)){
    
hist(xx[,i] , main = paste("Histogram of the",names[i],"feature") ,xlab = names[i])

}


#
# Out:
# Plot with title "Histogram of the Mean feature"
# Plot with title "Histogram of the Variance feature"
# Plot with title "Histogram of the Standard Deviation feature"
# Plot with title "Histogram of the Entropy feature"
# Plot with title "Histogram of the Skewness feature"
# Plot with title "Histogram of the Kurtosis feature"
# Plot with title "Histogram of the Contrast feature"
# Plot with title "Histogram of the Energy feature"
# Plot with title "Histogram of the ASM feature"
# Plot with title "Histogram of the Homogeneity feature"
# Plot with title "Histogram of the Dissimilarity feature"
# Plot with title "Histogram of the Correlation feature"
# Plot with title "Histogram of the Coarseness feature"
# Plot with title "Histogram of the PSNR feature"
# Plot with title "Histogram of the SSIM feature"
# Plot with title "Histogram of the MSE feature"
# Plot with title "Histogram of the DC feature"
